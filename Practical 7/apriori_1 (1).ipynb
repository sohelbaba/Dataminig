# %%
import numpy as np
import pandas as pd
from apyori import apriori;

# %%
data = pd.read_csv('store_data.csv', header=None);
data.head()

# %%
data.shape

# %%
records = [];
for i in range(0, 10):  
    records.append([str(data.values[i,j]) for j in range(0, 7)]);

#apriori
association_rules = apriori(records, min_support=0.05, min_confidence=0.03, min_lift=2, min_length=2);
association_results = list(association_rules);

len(association_results) 
#print(association_results)
# Out:
# 93

# %%
for item in association_results:
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: bread -> butter
# Support: 0.4
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.3
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> bread
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> bread
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> bread
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> curd
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: milk -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> curd
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: milk -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: curd -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> nan
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: yogurt -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: butter -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> nan
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.2
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.5
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: butter -> chocolate
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: yogurt -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> butter
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
# Rule: bread -> yogurt
# Support: 0.1
# Confidence: 1.0
# Lift: 2.0
# =====================================
